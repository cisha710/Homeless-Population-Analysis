# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import pathlib as path
import numpy as np

# %%
# Select which columns to keep
columns_to_keep = ['State',
                   'Year',
                   'Overall Homeless',
                   'Overall Homeless - Under 18',
                   'Overall Homeless - Age 18 to 24',
                   'Overall Homeless - Over 24']

# %%
# Filter by rows (only CA and TX)
df_2020 = pd.read_excel('resources/2007-2020-PIT-Estimates-by-state.xlsx', sheet_name = "2020")
ca_tx_2020 = df_2020[(df_2020['State'] == 'CA') | (df_2020['State'] == 'TX')]
df_filtered_2020 = ca_tx_2020[columns_to_keep]

df_2019 = pd.read_excel('resources/2007-2020-PIT-Estimates-by-state.xlsx', sheet_name = "2019")
ca_tx_2019 = df_2019[(df_2019['State'] == 'CA') | (df_2019['State'] == 'TX')]
df_filtered_2019 = ca_tx_2019[columns_to_keep]

df_2018 = pd.read_excel('resources/2007-2020-PIT-Estimates-by-state.xlsx', sheet_name = "2018")
ca_tx_2018 = df_2018[(df_2018['State'] == 'CA') | (df_2018['State'] == 'TX')]
df_filtered_2018 = ca_tx_2018[columns_to_keep]

df_2017 = pd.read_excel('resources/2007-2020-PIT-Estimates-by-state.xlsx', sheet_name = "2017")
ca_tx_2017 = df_2017[(df_2017['State'] == 'CA') | (df_2017['State'] == 'TX')]
df_filtered_2017 = ca_tx_2017[columns_to_keep]

df_2016 = pd.read_excel('resources/2007-2020-PIT-Estimates-by-state.xlsx', sheet_name = "2016")
ca_tx_2016 = df_2016[(df_2016['State'] == 'CA') | (df_2016['State'] == 'TX')]
df_filtered_2016 = ca_tx_2016[columns_to_keep]

df_2015 = pd.read_excel('resources/2007-2020-PIT-Estimates-by-state.xlsx', sheet_name = "2015")
ca_tx_2015 = df_2015[(df_2015['State'] == 'CA') | (df_2015['State'] == 'TX')]
df_filtered_2015 = ca_tx_2015[columns_to_keep]

df_2014 = pd.read_excel('resources/2007-2020-PIT-Estimates-by-state.xlsx', sheet_name = "2014")
ca_tx_2014 = df_2014[(df_2014['State'] == 'CA') | (df_2014['State'] == 'TX')]
df_filtered_2014 = ca_tx_2014[columns_to_keep]

df_2013 = pd.read_excel('resources/2007-2020-PIT-Estimates-by-state.xlsx', sheet_name = "2013")
ca_tx_2013 = df_2013[(df_2013['State'] == 'CA') | (df_2013['State'] == 'TX')]
df_filtered_2013 = ca_tx_2013[columns_to_keep]

# Combine rows into a few datasheet

combined_data = pd.concat([df_filtered_2013, 
                           df_filtered_2014,
                           df_filtered_2015, 
                           df_filtered_2016, 
                           df_filtered_2017,
                           df_filtered_2018,
                           df_filtered_2019,
                           df_filtered_2020
                           ], ignore_index=True)

combined_data
# Out:
#    State  Year Overall Homeless Overall Homeless - Under 18  \
# 0     CA  2013           118552                       16097
# 1     TX  2013            29615                        5478
# 2     CA  2014           113952                       15057
# 3     TX  2014            28495                        5873
# 4     CA  2015           115738                       13657
# 5     TX  2015            23678                        4529
# 6     CA  2016           118142                       12828
# 7     TX  2016            23122                        4615
# 8     CA  2017           131532                       14207
# 9     TX  2017            23548                        4286
# 10    CA  2018           129972                       13936
# 11    TX  2018            25310                        4101
# 12    CA  2019           151278                       14305
# 13    TX  2019            25848                        4249
# 14    CA  2020           161548                       16141
# ...

# %%
# Sort combined_data by like state
custom_order = ['CA', 'TX']
combined_data['State'] = pd.Categorical(combined_data['State'], categories=custom_order, ordered=True)
combined_data = combined_data.sort_values('State')
combined_data
# Out:
#    State  Year Overall Homeless Overall Homeless - Under 18  \
# 0     CA  2013           118552                       16097
# 2     CA  2014           113952                       15057
# 4     CA  2015           115738                       13657
# 6     CA  2016           118142                       12828
# 8     CA  2017           131532                       14207
# 10    CA  2018           129972                       13936
# 12    CA  2019           151278                       14305
# 14    CA  2020           161548                       16141
# 1     TX  2013            29615                        5478
# 3     TX  2014            28495                        5873
# 5     TX  2015            23678                        4529
# 7     TX  2016            23122                        4615
# 9     TX  2017            23548                        4286
# 11    TX  2018            25310                        4101
# 13    TX  2019            25848                        4249
# ...

# %%
#Getting only Texas data
combined_data_tx = combined_data.loc[combined_data["State"] == 'TX']
combined_data_tx = combined_data_tx.drop('Overall Homeless', axis=1)
combined_data_tx
# Out:
#    State  Year Overall Homeless - Under 18 Overall Homeless - Age 18 to 24  \
# 1     TX  2013                        5478                            2056
# 3     TX  2014                        5873                            2143
# 5     TX  2015                        4529                            1712
# 7     TX  2016                        4615                            1596
# 9     TX  2017                        4286                            1750
# 11    TX  2018                        4101                            1671
# 13    TX  2019                        4249                            1523
# 15    TX  2020                        4048                            1663
#
#    Overall Homeless - Over 24
# 1                       22081
# 3                       20479
# 5                       17437
# 7                       16911
# 9                       17512
# 11                      19538
# 13                      20076
# 15                      21518

# %% [markdown]
# # Age wise distribution of homeless population in Texas

# %%
# A stacked bar graph to show homeless count age wise in 2013-2020
multi_plot = combined_data_tx.plot(x="Year", kind="bar", figsize=(10,5), stacked=True)

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(combined_data_tx["Year"], rotation=0)

plt.title("Age wise distribution Homeless Population in Texas",fontsize=16)
plt.xlabel("Year")
plt.ylabel("#Homeless Count")

# Save the figure
plt.savefig("Output/HomelessVSAgeTexas.png")

plt.show()
plt.tight_layout()

# %% [markdown]
# Homeless population in Texas for age group -
# Under 18 - is gradually decreasing as the years pass by.
# 18 to 24 - is approximately same for all 7 years, but can see a small decrease in 2019 and 2020.
# Above 24 - is Significantly decreasing for mid years but can see an increasse again from 2018-2020

# %% [markdown]
# # # Age wise distribution of homeless population in CA

# %%
#Getting only California data
combined_data_ca = combined_data.loc[combined_data["State"] == 'CA']
combined_data_ca = combined_data_ca.drop('Overall Homeless', axis=1)
combined_data_ca
# Out:
#    State  Year Overall Homeless - Under 18 Overall Homeless - Age 18 to 24  \
# 0     CA  2013                       16097                           14366
# 2     CA  2014                       15057                           13853
# 4     CA  2015                       13657                           11645
# 6     CA  2016                       12828                           12160
# 8     CA  2017                       14207                           13276
# 10    CA  2018                       13936                           12678
# 12    CA  2019                       14305                           12673
# 14    CA  2020                       16141                           13391
#
#    Overall Homeless - Over 24
# 0                       88089
# 2                       85042
# 4                       90436
# 6                       93154
# 8                      104049
# 10                     103358
# 12                     124300
# 14                     132016

# %%
# A stacked bar graph to show homeless count age wise from 2013 to 2020
multi_plot = combined_data_ca.plot(x="Year", kind="bar", figsize=(10,5), stacked=True)

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(combined_data_ca["Year"], rotation=0)

plt.title("Homeless as per age in California",fontsize=16)
plt.xlabel("Year")
plt.ylabel("#Homeless Count")

# Save the figure
plt.savefig("Output/HomelessVSAgeCA.png")

plt.show()
plt.tight_layout()

# %% [markdown]
# Homeless population in Texas for age group -
# Under 18 - is decreasing in mid years and then there's a rise as move towards 2020.
# 18 to 24 - is approximately same for all 7 years.
# Above 24 - is Significantly increasing as we move towards 2020

# %%
#CA vs TX Overall Homeless Population

cd = combined_data
df = cd[['State','Year','Overall Homeless']]
ca_df = df[df.State=='CA'].set_index('Year').drop('State',axis=1)
tx_df = df[df.State=='TX'].set_index('Year').drop('State',axis=1)

plt.figure(figsize=[10,3])
plt.title("Overall Homeless Population CA vs TX",fontsize=16)
plt.xlabel("Year")
plt.ylabel("Overall Homeless Population")
plt.plot(ca_df, label='CA')
plt.plot(tx_df, label='TX')

# Save the figure
plt.savefig("Output/Overall Homeless Population CA vs TX.png")

plt.legend(loc='upper center')
plt.grid()

# %% [markdown]
# There is an increase in the homeless population in the state of California as compared to Texas in the span of 7 year starting from 2013 to 2020.
